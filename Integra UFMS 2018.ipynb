# %%
import camelot
import pandas as pd
from functools import reduce
import numpy as np

# %%
def get_data(tables):
    data_frames = []
    for i in range(len(tables)):
        data_frames.append(tables[i].df)
    return data_frames

# %%
data_frames = get_data(camelot.read_pdf('2018/prograd.pdf', pages='4-end', flavor='lattice', strip_text='\\n'))

# %%
#data_frames[0][0]=='Unidade'
#data_frames[0][data_frames[0][0]=='Unidade']

# %%
#data_frames[2].replace(regex='\\n', value=' ')

# %%
#data_frames[2][data_frames[2].isin(values=['']).all(axis=1)]

# %%
#data_frames[2][~data_frames[2].isin(values=['']).all(axis=1)] #retorna a negacao do de cima!

# %%
for i in data_frames: 
    if 6 in i: i.drop(6,axis=1,inplace=True) #REMOVE AS COLUNAS EM BRANCO

# %%
for df in data_frames:
    df[~df.isin(values=['']).all(axis=1)]

# %%
for i in range(len(data_frames)):
    data_frames[i] = data_frames[i][~data_frames[i].isin(values=['']).all(axis=1)]
    data_frames[i] = data_frames[i].replace(regex='\\n', value=' ')

# %%
#data_frames[0][0].str.contains("Data de apresentação") #NICEEE!!!

# %%
#data_frames[1][~data_frames[1][0].str.contains("Data de apresentação")] #nessa celula eu removo as tuplas q 
#tem 'data de apresentacao' na primeira linha

# %%
for i in range(len(data_frames)):
    data_frames[i] = data_frames[i][~data_frames[i][0].str.contains("Data de apresentação")]

# %%
#data_frames[8]
#'Unidade','Programa/Projeto','Coordenador','Área deConhecimento','Título trabalho','Apresentador'
#Removo as linhas que contem esses dados
for i in range(len(data_frames)):
    data_frames[i] = data_frames[i][~data_frames[i].isin(values=['Unidade','Programa/Projeto','Coordenador','Área deConhecimento','Título trabalho','Apresentador']).all(axis=1)]

# %%
df = reduce(lambda left,right: pd.merge(left,right,on=[0,1,2,3,4,5],how='outer'), data_frames)

# %%
df = df[~df.isin(values=[''])] #retorna NaN para os valores que sao string vazia, isso por causa da negacao

# %%
df.ffill(axis=0, inplace=True)

# %%
df.rename(columns={
    0:'Unidade', 1:'Programa/Projeto', 2:'Coordenador',
    3:'Área de Conhecimento', 4:'Título trabalho', 5:'Apresentador'},inplace=True)

# %%
df
# Out:
#      Unidade                                Programa/Projeto  \
# 0    Unidade                               Programa/ Projeto
# 1    Unidade                               Programa/ Projeto
# 2    Unidade                               Programa/ Projeto
# 3    Unidade                               Programa/ Projeto
# 4    Unidade                               Programa/ Projeto
# 5    Unidade                               Programa/ Projeto
# 6    Unidade                               Programa/ Projeto
# 7    Unidade                               Programa/ Projeto
# 8       CPTL                                  PET Enfermagem
# 9       CPTL                                  PET Enfermagem
# 10      CPTL                                  PET Enfermagem
# 11      CPTL                                  PET Enfermagem
# 12      CPTL                                  PET Enfermagem
# 13      CPTL                                  PET Enfermagem
# 14      Faed                             PET Educação Física
# 15      Faed                             PET Educação Física
# 16      Faed                             PET Educação Física
# 17      Faed                             PET Educação Física
# 18    Facfan                                    PET Farmácia
# 19    Facfan                                    PET Farmácia
# 20    Facfan                                    PET Farmácia
# 21    Facfan                                    PET Farmácia
# 22    Facfan                                    PET Farmácia
# 23    Facfan                                    PET Farmácia
# 24    Facfan                                    PET Farmácia
# 25     Faodo                                             PEG
# 26     Faodo                                             PEG
# 27     Faodo                                             PEG
# 28      CPPP                                   PET Fronteira
# 29      CPTL              PET Matemática Conexões de Saberes
# ..       ...                                             ...
# 108     CPNV                PET Pedagogia e Ciências Sociais
# 109     CPNV                PET Pedagogia e Ciências Sociais
# 110     CPNV                PET Pedagogia e Ciências Sociais
# 111     CPAN  PET Pedagogia e Psicologia Conexões de Saberes
# 112     CPAN  PET Pedagogia e Psicologia Conexões de Saberes
# 113     CPAN  PET Pedagogia e Psicologia Conexões de Saberes
# 114     CPAN  PET Pedagogia e Psicologia Conexões de Saberes
# 115     CPAR                                             PEG
# 116     CPAN                                      PIBID UFMS
# 117     CPAN                                      PIBID UFMS
# 118     CPAN                                      PIBID UFMS
# 119     CPNV                                      PIBID UFMS
# 120     CPNV                                      PIBID UFMS
# 121     CPTL                                      PIBID UFMS
# 122     FAED                                      PIBID UFMS
# 123     FAED                                      PIBID UFMS
# 124     FAED                                      PIBID UFMS
# 125     CPAN                                      PIBID UFMS
# 126     CPAN                                      PIBID UFMS
# 127     CPAN                                      PIBID UFMS
# 128     CPTL                                      PIBID UFMS
# 129     CPNV                                      PIBID UFMS
# 130     CPNV                                      PIBID UFMS
# 131     CPTL                                     PIBID CAPES
# 132     CPAN                                             PEG
# 133     CPTL                                      PIBID UFMS
# 134    FAALC                                      PIBID UFMS
# 135    FAALC                                      PIBID UFMS
# 136    FAALC                                      PIBID UFMS
# 137     CPTL                                      PIBID UFMS
#
#                                 Coordenador         Área de Conhecimento  \
# 0                               Coordenador         Área de Conhecimento
# 1                               Coordenador         Área de Conhecimento
# 2                               Coordenador         Área de Conhecimento
# 3                               Coordenador         Área de Conhecimento
# 4                               Coordenador         Área de Conhecimento
# 5                               Coordenador         Área de Conhecimento
# 6                               Coordenador         Área de Conhecimento
# 7                               Coordenador         Área de Conhecimento
# 8                       Sonia Regina Jurado            Ciências da Saúde
# 9                       Sonia Regina Jurado            Ciências da Saúde
# 10                      Sonia Regina Jurado            Ciências da Saúde
# 11                      Sonia Regina Jurado            Ciências da Saúde
# 12                      Sonia Regina Jurado            Ciências da Saúde
# 13                      Sonia Regina Jurado            Ciências da Saúde
# 14           Junior Vagner Pereira da Silva            Ciências da Saúde
# 15           Junior Vagner Pereira da Silva            Ciências da Saúde
# 16           Junior Vagner Pereira da Silva            Ciências da Saúde
# 17           Junior Vagner Pereira da Silva            Ciências da Saúde
# 9    A saúde do escolar e os projetos de extensão d...
# 10   Oficina de primeiros socorros como atividade d...
# 11   Espiritualidade e a assistência de enfermagem:...
# 12   Rodas de conversa e utilização da caderneta da...
# 13   Tuberculose no Brasil – epidemiologia e o pape...
# 14   Colônia de férias na universidade federal de m...
# 15   O futebol desenvolvido nas escolas públicas de...
# 16   Qualidade de vida e nível de atividade física ...
# 17                              5º Ação PET Sangue Bom
# 18   Desenvolvimento de formulações a base de plant...
# 19   A importância da monitoria no processo de apre...
# 20   Ações em saúde: como o consumo de álcool afeta...
# 21   O impacto da monitoria de histologia básica no...
# 22   Monitoria: ferramenta de aprendizagem e diminu...
# 23   A importância do descarte correto e os medicam...
# 24   A importância do nivelamento a formação acadêm...
# 25   Princípios da Humanização no Atendimento Odont...
# 26   Cartilhas de Orientações Odontológicas na área...
# 27   Humanização no Atendimento Odontológico - Uma ...
# 28   Recepção de alunos ingressantes na graduação e...
# 29   Contadores de histórias: incentivando a cultur...
# ..                                                 ...
# 108  I encontro desportivo e cultural: contribuiçõe...
# 109  Ações do grupo PET incentivam o respeito à div...
# 110  A contribuição da pesquisa individual na vida ...
# 111  Levantamento do perfil dos inscritos no cursin...
# 112  Oficina de estudos: estratégias e planejamento...
# 113           PET/Conexões de Saberes: Network no CPAN
# 114                        Universidade vai às Escolas
# 115               Feminismo e Análise do Comportamento
# 116                               O uso da calculadora
# 117              Demonstrações do teorema de Pitágoras
# 118                   Geometria analítica e o Geogebra
# 119  Da leitura do lúdico à leitura das letras: Ini...
# 120  Geometrizando no primeiro ano do ensino fundam...
# 121  Lendo, escrevendo, cantando e falando da cultu...
# 122  Práticas colaborativas entre a escola e a univ...
# 123                 Escola: Espaço de formação docente
# 124  Repensando práticas pedagógicas na educação in...
# 125  A Ásia, mapas temáticos e o conceito de region...
# 126  Trabalho e Técnicas – Construindo uma Aprendiz...
# 127                       História pra que e pra quem?
# 128               PIBID UFMS: História em perspectivas
# 129  Conceitos dos principais teóricos da sociologi...
# 130  Movimentos sociais e ensino médio: Possibilida...
# 131              PIBID CAPES: História em perspectivas
# 132  Reflexões sobre a monitoria de ensino em teori...
# 133       Preservação Ambiental um Compromisso de Vida
# 134  Além das palavras: leitura e escrita com base ...
# 135  O gênero imita a vida ou a vida imita o gênero...
# 136  A contribuição dos gêneros para o ensino e apr...
# 137  O diálogo entre a literatura e a sociedade: Co...
#
#                                           Apresentador
# 0                                         Apresentador
# 1                                         Apresentador
# 2                                         Apresentador
# 3                                         Apresentador
# 4                                         Apresentador
# 5                                         Apresentador
# 6                                         Apresentador
# 7                                         Apresentador
# 8    Cauane Cristina Marceliano, Izabela Carvalho V...
# 9    Anna Clara Freitas Maia, Letícia Akie Nagata, ...
